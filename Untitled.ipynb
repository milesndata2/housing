# %%
import pandas as pd

# %%
SFRcounty=pd.read_csv('http://files.zillowstatic.com/research/public/County/County_Zhvi_SingleFamilyResidence.csv')
SFRcounty.head(20)
# Out:
#     RegionID      RegionName State                           Metro  \
# 0       3101     Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 1        139            Cook    IL                         Chicago
# 2       2402        Maricopa    AZ                         Phoenix
# 3       2841       San Diego    CA                       San Diego
# 4       1286          Orange    CA  Los Angeles-Long Beach-Anaheim
# 5        581           Kings    NY                        New York
# 6       2964      Miami-Dade    FL           Miami-Fort Lauderdale
# 7        978          Dallas    TX               Dallas-Fort Worth
# 8       1347          Queens    NY                        New York
# 9       2832       Riverside    CA                       Riverside
# 10      3250  San Bernardino    CA                       Riverside
# 11       445           Clark    NV                       Las Vegas
# 12       207            King    WA                         Seattle
# ...

# %%
sqft=pd.read_csv('http://files.zillowstatic.com/research/public/County/County_MedianValuePerSqft_AllHomes.csv')
sqft.head(20)
# Out:
#     RegionID      RegionName State                           Metro  \
# 0       3101     Los Angeles    CA  Los Angeles-Long Beach-Anaheim
# 1        139            Cook    IL                         Chicago
# 2       2402        Maricopa    AZ                         Phoenix
# 3       2841       San Diego    CA                       San Diego
# 4       1286          Orange    CA  Los Angeles-Long Beach-Anaheim
# 5       2964      Miami-Dade    FL           Miami-Fort Lauderdale
# 6        978          Dallas    TX               Dallas-Fort Worth
# 7       1347          Queens    NY                        New York
# 8       2832       Riverside    CA                       Riverside
# 9       3250  San Bernardino    CA                       Riverside
# 10       445           Clark    NV                       Las Vegas
# 11       207            King    WA                         Seattle
# 12       791           Wayne    MI                         Detroit
# ...

# %%
cenhousing=pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2000-2010/intercensal/housing/h')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-10-03abed0d4eaf> in <module>()
# ----> 1 cenhousing=pd.read_csv('https://www2.census.gov/programs-surveys/popest/datasets/2000-2010/intercensal/housing/h')
#
# ...
